# %%
#week 1

#this is a single line comment
print("xyz")
"""this is a multi line comment
which is more than one line"""
print("Hello World")
# Out:
# xyz
# Hello World

# %%
#datatypes
x=1  #int
y=2.8  #float
z=1j  #complex
#to verify the type of any object in python, use type() function:
print(x,type(x))
print(y, type(y))
print(z, type(z))
# Out:
# 1 <class 'int'>
# 2.8 <class 'float'>
# 1j <class 'complex'>

# %%
x = 1.10
y = 1.0
z = -35.59
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x = int(1) #x will be 1
y = int(2.8) #y will be 2
z = int("3") #z will be 3
#in type casting , since we used int the values will be converted as int type only
print(x,y,z)
# Out:
# 1 2 3

# %%
x = float(1)
y = float(2.8)
z = float("3")
w = float("4.2")
print(x,y,z,w)
# Out:
# 1.0 2.8 3.0 4.2

# %%
x = str("s1") #x will be 's1'
y = str(2)
z = str("NO")
print(x,y,z)
# Out:
# s1 2 NO

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %%
a = """Strings in python are surrounded by either
single quotation marks, or double quotation marks."""
print(a)
# Out:
# Strings in python are surrounded by either
# single quotation marks, or double quotation marks.

# %%
b = "KLH BOWRAMPET"
print(b)
# Out:
# KLH BOWRAMPET

# %%
#slicing from starting
b = "KLH BOWRAMPET"
print(b[:5])
# Out:
# KLH B

# %%
#slicing to the end
b = "KLH BOWRAMPET"
print(b[2:])
# Out:
# H BOWRAMPET

# %%
#slicing
b = "KLH BOWRAMPET"
print(b[2:5])
# Out:
# H B

# %%
b = " KONERU LAKSHMAIAHA EDUCATIONAL FOUNDATION "
print(b[-10:-4])
# Out:
# OUNDAT

# %%
#String Methods
A = " KONERU LAKSHMAIAHA EDUCATIONAL FOUNDATION "
print("capitalize():", A.capitalize()) #Converts the first character to upper
print("casefold():", A.casefold()) #Converts string into lower case
print("center():", A.center(60,'*')) #returns a centered string
print("count():", A.count("A")) #returns the number of times a specified value occurs in a string
print("find():", A.find("EDUCATIONAL")) #searchs the string for a specified value and returns the position of where it was found
print("index():", A.index("FOUNDATION")) #
print("islower():", A.islower())
print("isupper():", A.isupper())
print("join():", "-".join(A))
print("lower():", A.lower())
print("replace():", A.replace("FOUNDATIONAL", "UNIVERSITY"))
print("swapcase():", A.swapcase())
print("title():", A.title())
print("upper():", A.upper())
print("zfill():", A.zfill(50))
# Out:
# capitalize():  koneru lakshmaiaha educational foundation
# casefold():  koneru lakshmaiaha educational foundation
# center(): ******** KONERU LAKSHMAIAHA EDUCATIONAL FOUNDATION *********
# count(): 7
# find(): 20
# index(): 32
# islower(): False
# isupper(): True
# join():  -K-O-N-E-R-U- -L-A-K-S-H-M-A-I-A-H-A- -E-D-U-C-A-T-I-O-N-A-L- -F-O-U-N-D-A-T-I-O-N-
# lower():  koneru lakshmaiaha educational foundation
# replace():  KONERU LAKSHMAIAHA EDUCATIONAL FOUNDATION
# swapcase():  koneru lakshmaiaha educational foundation
# title():  Koneru Lakshmaiaha Educational Foundation
# upper():  KONERU LAKSHMAIAHA EDUCATIONAL FOUNDATION
# zfill(): 0000000 KONERU LAKSHMAIAHA EDUCATIONAL FOUNDATION

# %%
#week 2
#################

#handling missing values
#mean median mode imputation:
import pandas as pd
import numpy as np
#sample dataset
df = pd.DataFrame({ 'Age': [25,30,np.nan,40,35],
    'Department':['HR','Finance','Finance',np.nan,'IT']})
#display Original dataset
print("Original Dataset(With Missing Values):")
print(df)
#mean of numeric
df['Age'] = df['Age'].fillna(df['Age'].mean())
#mode for catogorial
df['Department'] = df['Department'].fillna(df['Department'].mode()[0])
print(df)
# Out:
# Original Dataset(With Missing Values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  32.5    Finance
# 3  40.0    Finance
# 4  35.0         IT

# %%
#2. Forward/Backward Fill
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'Age':[25,30,np.nan,40,35],
    'Department':['HR', 'Finance','Finance',np.nan,'IT']
})
#display original dataset
print("Original Dataset (With Missing Values):")
print(df)
#forward fill(use previous value)
df_ffill = df.copy()
df_ffill.ffill(inplace=True)
print(df_ffill)
#backward fill(use next value)
df_bfill = df.copy()
df_bfill.bfill(inplace=True)
print(df_bfill)
# Out:
# Original Dataset (With Missing Values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  30.0    Finance
# 3  40.0    Finance
# 4  35.0         IT
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  40.0    Finance
# 3  40.0         IT
# 4  35.0         IT

# %%
#3. a deletion (drop rows or columns)
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'Age':[25,30,np.nan,40,35],
    'Department':['HR', 'Finance','Finance',np.nan,'IT']
})
#display original dataset
print("Original Dataset")
print(df)
#drop rows with missing values
df_drop_rows = df.dropna()
print("After dropping rows:\n",df_drop_rows)
#drop columns with missing values
df_drop_cols = df.dropna(axis=1)
print("After dropping columns:\n",df_drop_cols)
# Out:
# Original Dataset
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
# After dropping rows:
#      Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 4  35.0         IT
# After dropping columns:
#  Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
#3b.Removing duplicates(Exact Match Removal)
import pandas as pd
#sample dataset with duplicates
df = pd.DataFrame({
    'ID': [1,2,2,3,4,4],
    'Name':['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'David'],
    'Age': [25,30,30,35,40,40]
})

print("Original Data:\n", df)
#remove exact duplicates
df_exact = df.drop_duplicates()
print("\nAfter Exact Match Removal:\n", df_exact)
# Out:
# Original Data:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# After Exact Match Removal:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
#3b.Removing duplicates(Subset-Based Removal)
import pandas as pd
#sample dataset with duplicates
df = pd.DataFrame({
    'ID': [1,2,2,3,4,4,5],
    'Name':['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'David','David'],
    'Age': [25,30,30,35,40,40,40]
})
print("Original Data:\n", df)
#remove duplicates based only on'ID'
df_subset_id = df.drop_duplicates(subset = ['ID'])
print("\nAfter Subset-Based Removal (ID):\n", df_subset_id)
#remove duplicates based only on 'name'
df_subset_name = df.drop_duplicates(subset = ['Name'])
print("\nAfter Subset-Based Removal (Name):\n",df_subset_name)
# Out:
# Original Data:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
# 6   5    David   40
#
# After Subset-Based Removal (ID):
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 6   5    David   40
#
# After Subset-Based Removal (Name):
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
#3.b Removing Duplicates(Correcting Incosisting Formats)
#3.b.a Data Standardization(ISO 8601 format)
import pandas as pd
#sample dataset with inconsistent data formats
df = pd.DataFrame({
    'Data':['2025-01-05','05/01/2025', 'Jan 5,2025', '2025.01.05']
})
print("Original Date:\n",df)
#convert all dates to standard Iso format(yyyy-mm-dd)
df['Data'] = pd.to_datetime(df['Data'],errors = 'coerce').dt.strftime('%Y-%M-%D')
print(df)
# Out:
# Original Date:
#           Data
# 0  2025-01-05
# 1  05/01/2025
# 2  Jan 5,2025
# 3  2025.01.05
#                Data
# 0  2025-00-01/05/25
# 1               NaN
# 2               NaN
# 3               NaN

# %%
#3.b Removing duplicates(correcting inconsistent formats)
#3. b.b case Normalization (lowercase/uppercase)
#sample dataset with inconsistent text cases
df = pd.DataFrame({
    'Name':['Alice', 'BOB', 'charlie', 'DAVID']
})
print("Original Data:\n", df)
#Convert all names to lowercase
df['Name_lower'] = df['Name'].str.lower()
#Convert all names to uppercase
df['Name_upper'] = df['Name'].str.upper()
print(df)
# Out:
# Original Data:
#        Name
# 0    Alice
# 1      BOB
# 2  charlie
# 3    DAVID
#       Name Name_lower Name_upper
# 0    Alice      alice      ALICE
# 1      BOB        bob        BOB
# 2  charlie    charlie    CHARLIE
# 3    DAVID      david      DAVID

# %%
#week 3
#3.Similarity and Dissimilarity measures and data analysis
#3.1 Vector- based distance measures(euclidean distance)
import numpy as np
from scipy.spatial import distance
pointA=np.array([2,4,6])
pointB=np.array([5,1,9])
#eucldiean distance- find how far these two points are from each other
eclu_dist=distance.euclidean(pointA,pointB)
print("Euclidean Distance:",eclu_dist)
#similiarity (inverse of distance)
similarity_dist=1/(1+eclu_dist)
print("Eucldeian Similiarity: ",similarity_dist)
# Out:
# Euclidean Distance: 5.196152422706632
# Eucldeian Similiarity:  0.16139047779640892

# %%
#3.Similarity and Dissimilarity measures and data analysis
#3.1 Vector- based distance measures(Manhattan distance) 
import numpy as np
from scipy.spatial import distance
pointA=np.array([2,4,6])
pointB=np.array([5,1,9])
#Manhattan distance
manhattan_dist = distance.cityblock(pointA,pointB)
print("Manhattan Distance:", manhattan_dist)
#Similarity(inverse of distance)
similarity_manhattan = 1/(1+manhattan_dist)
print("Manhattan Similarity:",similarity_manhattan)
# Out:
# Manhattan Distance: 9
# Manhattan Similarity: 0.1

# %%
#3.Similarity and Dissimilarity measures and data analysis
#3.1 Vector- based distance measures(Minkowski Distance)
import numpy as np
from scipy.spatial import distance
pointA=np.array([2,4,6])
pointB=np.array([5,1,9])
#Minkowski Distance with p=3
minkowski_dist_p3 = distance.minkowski(pointA,pointB, p=3)
print("Minkowski Distance (p=3):",minkowski_dist_p3)

#similarity(inverse of distance)
similarity_minkowski = 1/(1+minkowski_dist_p3)
print("Minkowski Similarity (p=3):", similarity_minkowski)
# Out:
# Minkowski Distance (p=3): 4.3267487109222245
# Minkowski Similarity (p=3): 0.1877317767871331

# %%
#3.Similarity and Dissimilarity measures and data analysis
#3.2 Statistical measures (pearson correlation)
import pandas as pd
#example dataset
df = pd.DataFrame({
    'X': [10,20,30,40,50],
    'Y': [12,24,33,45,60]
})
#pearson correlation matrix
corr_matrix = df.corr(method='pearson')
print("Pearson Correlation Matrix:\n", corr_matrix)
#for dataset:
#print("\n Pearson Correlation Dataset:\n")
#df = pd.read_csv("pearson_correlation_dataset.csv")
#print(df.corr(method='pearson'))
# Out:
# Pearson Correlation Matrix:
#            X         Y
# X  1.000000  0.996403
# Y  0.996403  1.000000

# %%
#3.2 Statistical Measures(spearman rank correlation)
import pandas as pd
from scipy.stats import spearmanr
#example dataset
({
'X': [10,20,30,40,50],
'Y': [12,18,33,47,55]
})
#spearman correaltion coeeficient and p-value
corr_value,p_value = spearmanr(df['X'], df['Y'])
print(f"Spearman Correlation Coefficient: {corr_value}")
print(f"P-value: {p_value}")

#for dataset:
#print("\n spearman Correlation Dataset:\n")
#df = pd.read_csv("pearson_correlation_dataset.csv")
#print(df.corr(method='spearman'))
# Out:
# Spearman Correlation Coefficient: 0.9999999999999999
# P-value: 1.4042654220543602e-24

# %%
#3.2 Edit-based measures(string/text data- hamming distance)
def hamming_distance(str1, str2):
    #ensure strings are of equal length
    if len(str1) != len(str2):
        raise ValueError("Strings must be of equal length")
    #count differing positions
    return sum(ch1 != ch2 for ch1,ch2 in zip(str1,str2))
#example usage
s1 = "karolin"
s2 = "kathrin"

dist = hamming_distance(s1,s2)
print(f"Hamming Distance between '{s1}' and '{s2}':{dist}")
# Out:
# Hamming Distance between 'karolin' and 'kathrin':3

# %%
#3. Similarity and dissimilarity measures for data analysis.
#3.4 token based measures(sets/text - jaccard index)

def jaccard_index(str1, str2):
    set1, set2 = set(str1.split()), set(str2.split())
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    return len(intersection)/len(union)
#example usage
s1 = "data science is fun"
s2 = "science makes data useful"
print("Jaccard Index:", jaccard_index(s1, s2))
# Out:
# Jaccard Index: 0.3333333333333333
